# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.DataFrame(np.random.randn(4,5),columns=['data1','data2','data3','data4','data5'])
d
# Out:
#       data1     data2     data3     data4     data5
# 0 -1.476609 -0.672691  0.657167 -0.771830  1.051534
# 1 -0.387281  1.770682  0.391415  0.562516 -0.232103
# 2  0.266531  0.549499  1.781932 -0.740393  0.171861
# 3 -0.840985 -0.764730  1.013900  0.366810  0.924450

# %% [markdown]
# ## Line Plot

# %%
d.plot

# %%
d[['data2','data5']].plot(color=['red','magenta'],linestyle = '--',title='Pandas plotting')
# Out:
# <AxesSubplot:title={'center':'Pandas plotting'}>

# %%
#drop one columns
d.drop(columns=['data5'],inplace=True)

# %%
d
# Out:
#       data1     data2     data3     data4
# 0 -1.476609 -0.672691  0.657167 -0.771830
# 1 -0.387281  1.770682  0.391415  0.562516
# 2  0.266531  0.549499  1.781932 -0.740393
# 3 -0.840985 -0.764730  1.013900  0.366810

# %%
#To separate plot for each column use subplots
d.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
d.plot(subplots =True ,figsize =(12,10))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
d.plot(subplots =True,figsize =(12,10),layout=(2,3));

# %%
d.plot(x='data2',y='data3')
# Out:
# <AxesSubplot:xlabel='data2'>

# %% [markdown]
# # Data Selection using loc and iloc

# %%
d[:2]
# Out:
#       data1     data2     data3     data4
# 0 -1.476609 -0.672691  0.657167 -0.771830
# 1 -0.387281  1.770682  0.391415  0.562516

# %% [markdown]
# ## loc : label based Selection

# %%
d.loc[::-1,'data2':'data4'] #in loc stop is inclusive
# Out:
#       data2     data3     data4
# 3 -0.764730  1.013900  0.366810
# 2  0.549499  1.781932 -0.740393
# 1  1.770682  0.391415  0.562516
# 0 -0.672691  0.657167 -0.771830

# %%
d.loc[:2]
# Out:
#       data1     data2     data3     data4
# 0 -1.476609 -0.672691  0.657167 -0.771830
# 1 -0.387281  1.770682  0.391415  0.562516
# 2  0.266531  0.549499  1.781932 -0.740393

# %%
#d.loc[:,['data1','data4']]
d.loc[:,'data1'::3]
# Out:
#       data1     data4
# 0 -1.476609 -0.771830
# 1 -0.387281  0.562516
# 2  0.266531 -0.740393
# 3 -0.840985  0.366810

# %%
#iloc:index based location
d.iloc[:,1:3] #stop is exclusive
# Out:
#       data2     data3
# 0 -0.672691  0.657167
# 1  1.770682  0.391415
# 2  0.549499  1.781932
# 3 -0.764730  1.013900

# %%
d.iloc[:,1::2]
# Out:
#       data2     data4
# 0 -0.672691 -0.771830
# 1  1.770682  0.562516
# 2  0.549499 -0.740393
# 3 -0.764730  0.366810

# %%
d.iloc[:,3:0:-1]
# Out:
#       data4     data3     data2
# 0 -0.771830  0.657167 -0.672691
# 1  0.562516  0.391415  1.770682
# 2 -0.740393  1.781932  0.549499
# 3  0.366810  1.013900 -0.764730

# %%
d.iloc[:,:0:-1]  #or we can use d.iloc[:,[3,2,1]]
# Out:
#       data4     data3     data2
# 0 -0.771830  0.657167 -0.672691
# 1  0.562516  0.391415  1.770682
# 2 -0.740393  1.781932  0.549499
# 3  0.366810  1.013900 -0.764730

# %% [markdown]
# ## Bar Plot

# %%
d.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
d.iloc[:,[3,2]].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
d2=pd.Series([230,450,677,1000],name='central')
d2.plot(kind='pie',title='Sample',)
# Out:
# <AxesSubplot:title={'center':'Sample'}, ylabel='central'>

# %% [markdown]
# ## Multiple plot using subplot

# %%
# 2x2 layout== 4 plots
plt.figure(figsize=(16,12))

plt.subplot(221)
plt.plot(d['data1'],label='data1')
plt.title('Plot1')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()

plt.subplot(222)
plt.bar(range(4),d['data2'])

plt.subplot(223)
plt.hist(d['data3'],color='red')

plt.subplot(224)
plt.plot(d['data4'],'--ko')

plt.suptitle('4 in one plot')
# Out:
# Text(0.5, 0.98, '4 in one plot')
